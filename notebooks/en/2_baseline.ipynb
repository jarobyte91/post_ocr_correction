# %%
import torch
import torch.utils.data as tud
import torch.nn as nn
import pickle
from tqdm.notebook import tqdm
import datetime
import matplotlib.pyplot as plt
import importlib
import sys
import pandas as pd

# %%
# !pwd
# Out:
# /home/jarobyte/guemes/icdar/en

# %%
sys.path.append("/home/jarobyte/guemes/lib")

# %%
from pytorch_decoding.seq2seq import Transformer

# %%
scratch = "/home/jarobyte/scratch/guemes/icdar/en/"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
char2i = pickle.load(open(scratch + "data/char2i.pkl", "rb"))

# %%
i2char = pickle.load(open(scratch + "data/i2char.pkl", "rb"))

# %% [markdown]
# # data

# %%
train_size = 1000000

dev_size = 1000000

# train_size = 1000

# dev_size = 100

# %% [markdown]
# ## train

# %%
train_source = torch.load(scratch + "data/train_source.pt")[:train_size].to(device)
train_source.shape
# Out:
# torch.Size([213815, 102])

# %%
train_target = torch.load(scratch + "data/train_target.pt")[:train_size].to(device)
train_target.shape
# Out:
# torch.Size([213815, 102])

# %%
dev_source = torch.load(scratch + "data/dev_source.pt")[:dev_size].to(device)
dev_source.shape
# Out:
# torch.Size([11394, 102])

# %%
dev_target = torch.load(scratch + "data/dev_target.pt")[:dev_size].to(device)
dev_target.shape
# Out:
# torch.Size([11394, 102])

# %% [markdown]
# # model

# %%
model = Transformer(char2i, 
                    i2char, 
                    max_sequence_length = 110,
                    embedding_dimension = 512,
                    feedforward_dimension = 2048,
                    attention_heads = 8,
                    encoder_layers = 4,
                    decoder_layers = 4)
model.to(device)

log = model.fit(train_source, 
                train_target, 
                dev_source, 
                dev_target, 
                epochs = 1, 
                progress_bar = 2, 
                learning_rate = 10**-4)
# Out:
# Model: Transformer
# Tokens in the input vocabulary: 164
# Tokens in the output vocabulary: 164
# Max sequence length: 110
# Embedding dimension: 512
# Feedforward dimension: 2048
# Encoder layers: 4
# Decoder layers: 4
# Attention heads: 8
# Activation: relu
# Dropout: 0.0
# Trainable parameters: 29,736,100
#   0%|          | 0/1 [00:00<?, ?it/s]
# Training started
# Epochs: 1
# Learning rate: 0.0001
# Weight decay: 0
# Epoch | Train                 | Development           | Minutes
#       | Loss     | Error Rate | Loss     | Error Rate |
# ---------------------------------------------------------------
#   0%|          | 0/2139 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-a577ced8ef7f> in <module>
#      15                 epochs = 1,
#      16                 progress_bar = 2,
# ---> 17                 learning_rate = 10**-4)
#
# ~/guemes/lib/pytorch_decoding/seq2seq.py in fit(self, X_train, Y_train, X_dev, Y_dev, batch_size, epochs, learning_rate, weight_decay, progress_bar, save_path)
#     280                 y = y[:, 1:]
#     281                 loss = criterion(probabilities, y)
# --> 282                 loss.backward()
#     283                 optimizer.step()
#     284                 optimizer.zero_grad()
#
# ~/envs/guemes/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~/envs/guemes/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# KeyboardInterrupt:

# %%
idx, probs = model.predict(dev_source)
# Out:
#   0%|          | 0/114 [00:00<?, ?it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
#   0%|          | 0/101 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-cbd1fe18b339> in <module>
# ----> 1 idx, probs = model.predict(dev_source)
#
# ~/guemes/lib/pytorch_decoding/seq2seq.py in predict(self, X, predictions, method, main_batch_size, main_progress_bar, **kwargs)
#     450                 batch_Y, batch_probabilities = self.beam_search(X = x[0],
#     451                                                                 predictions = predictions,
# --> 452                                                                 **kwargs)
#     453                 # In this case, we only return the best candidate for each example
#     454                 Y.append(batch_Y[:, 0, :])
#
# ~/guemes/lib/pytorch_decoding/seq2seq.py in beam_search(self, X, predictions, beam_width, batch_size, progress_bar)
#     165                     iterator = tqdm(iterator)
#     166                 for x, y in iterator:
# --> 167                     next_probabilities.append(self.forward(x, y)[:, -1, :].log_softmax(-1))
#     168                 next_probabilities = torch.cat(next_probabilities, axis = 0)
#     169                 next_probabilities = next_probabilities.reshape((-1, beam_width, next_probabilities.shape[-1]))
#
# ~/guemes/lib/pytorch_decoding/seq2seq.py in forward(self, X, Y)
#     853         transformer_output = self.transformer.forward(src = X,
#     854                                                       tgt = Y,
# --> 855                                                       tgt_mask = mask)
#     856         transformer_output = transformer_output.transpose(0, 1)
#     857         return self.output_layer(transformer_output)
#
# ~/envs/guemes/lib/python3.7/site-packages/torch/nn/modules/transformer.py in forward(self, src, tgt, src_mask, tgt_mask, memory_mask, src_key_padding_mask, tgt_key_padding_mask, memory_key_padding_mask)
#     124         output = self.decoder(tgt, memory, tgt_mask=tgt_mask, memory_mask=memory_mask,
#     125                               tgt_key_padding_mask=tgt_key_padding_mask,
# --> 126                               memory_key_padding_mask=memory_key_padding_mask)
#     127         return output
#     128
#
# ~/envs/guemes/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/envs/guemes/lib/python3.7/site-packages/torch/nn/modules/transformer.py in forward(self, tgt, memory, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask)
#     232                          memory_mask=memory_mask,
#     233                          tgt_key_padding_mask=tgt_key_padding_mask,
# --> 234                          memory_key_padding_mask=memory_key_padding_mask)
#     235
#     236         if self.norm is not None:
#
# ~/envs/guemes/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/envs/guemes/lib/python3.7/site-packages/torch/nn/modules/transformer.py in forward(self, tgt, memory, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask)
#     368                                    key_padding_mask=memory_key_padding_mask)[0]
#     369         tgt = tgt + self.dropout2(tgt2)
# --> 370         tgt = self.norm2(tgt)
#     371         tgt2 = self.linear2(self.dropout(self.activation(self.linear1(tgt))))
#     372         tgt = tgt + self.dropout3(tgt2)
#
# ~/envs/guemes/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/envs/guemes/lib/python3.7/site-packages/torch/nn/modules/normalization.py in forward(self, input)
#     168     def forward(self, input: Tensor) -> Tensor:
#     169         return F.layer_norm(
# --> 170             input, self.normalized_shape, self.weight, self.bias, self.eps)
#     171
#     172     def extra_repr(self) -> Tensor:
#
# ~/envs/guemes/lib/python3.7/site-packages/torch/nn/functional.py in layer_norm(input, normalized_shape, weight, bias, eps)
#    2093                 layer_norm, (input,), input, normalized_shape, weight=weight, bias=bias, eps=eps)
#    2094     return torch.layer_norm(input, normalized_shape, weight, bias, eps,
# -> 2095                             torch.backends.cudnn.enabled)
#    2096
#    2097
#
# KeyboardInterrupt:

# %%
model.tensor2text(idx)
# Out:
# ['<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ',
#  '<START>                                                                                                      ']

# %%
model.tensor2text(train_target[:10])
# Out:
# ['<START> CONCERNING By J. T. DESAGULIERS, LL.D. F.R.<END>',
#  '<START> CONCERNING By J. T. DESAGULIERS, LL.D. F.R.<END>',
#  '<START> CONCERNING By J. T. DESAGULIERS, LL.D. F.R.<END>',
#  '<START> CONCERNING By J. T. DESAGULIERS, LL.D. F.R.<END>',
#  '<START> CONCERNING By J. T. DESAGULIERS, LL.D. F.R.<END>',
#  '<START> CONCERNING By J. T. DESAGULIERS, LL.D. F.R.<END>',
#  '<START> CONCERNING By J. T. DESAGULIERS, LL.D. F.R.<END>',
#  '<START> CONCERNING By J. T. DESAGULIERS, LL.D. F.R.<END>',
#  '<START> CONCERNING By J. T. DESAGULIERS, LL.D. F.R.<END>',
#  '<START> CONCERNING By J. T. DESAGULIERS, LL.D. F.R.<END>']

# %%
model.tensor2text(train_source[:10])
# Out:
# ['<START>A DISSERTATION CONCERNING ELECTRICITY. By J. T.DESJGULIERS, LL.D. F.R.S, Chaplain to His Royal High<END>',
#  '<START> DISSERTATION CONCERNING ELECTRICITY. By J. T.DESJGULIERS, LL.D. F.R.S, Chaplain to His Royal Highn<END>',
#  '<START>DISSERTATION CONCERNING ELECTRICITY. By J. T.DESJGULIERS, LL.D. F.R.S, Chaplain to His Royal Highne<END>',
#  '<START>ISSERTATION CONCERNING ELECTRICITY. By J. T.DESJGULIERS, LL.D. F.R.S, Chaplain to His Royal Highnes<END>',
#  '<START>SSERTATION CONCERNING ELECTRICITY. By J. T.DESJGULIERS, LL.D. F.R.S, Chaplain to His Royal Highness<END>',
#  '<START>SERTATION CONCERNING ELECTRICITY. By J. T.DESJGULIERS, LL.D. F.R.S, Chaplain to His Royal Highness <END>',
#  '<START>ERTATION CONCERNING ELECTRICITY. By J. T.DESJGULIERS, LL.D. F.R.S, Chaplain to His Royal Highness t<END>',
#  '<START>RTATION CONCERNING ELECTRICITY. By J. T.DESJGULIERS, LL.D. F.R.S, Chaplain to His Royal Highness th<END>',
#  '<START>TATION CONCERNING ELECTRICITY. By J. T.DESJGULIERS, LL.D. F.R.S, Chaplain to His Royal Highness the<END>',
#  '<START>ATION CONCERNING ELECTRICITY. By J. T.DESJGULIERS, LL.D. F.R.S, Chaplain to His Royal Highness the <END>']
